# %% [markdown]
# ### contents
#
# Note:1
# 1. Time Space comlexity Basic Idea
# 2. Binary Search
# 3. Findinf a common elnet in two list
# 4. Finding a common elemnt using Hastable/Dict (Tradeoff)

# %% [markdown]
# # 1. Space and Time Complexity

# %%
#Example

import random
l1 = list(range(100))
random.shuffle(l1)

Flag=False;      
q =310;            #line has 1 unit of time of computation
count=0
for i in l1:       #4lines has time computation = 4n 
    if i==q:
        print("Found")
        Flag= True
        break;
        
if Flag==False:
    print("Not Found")
# Out:
# Not Found

# %% [markdown]
# ![Screenshot%20%28118%29.png](attachment:Screenshot%20%28118%29.png)

# %% [markdown]
# ![Screenshot%20%28119%29.png](attachment:Screenshot%20%28119%29.png)

# %%
Geeks for Geeks

# %% [markdown]
# #  8.2 Binary Search
#
# - Binary Search is a searching algorithm for finding an element's position in a sorted array.
#
# - Binary search can be implemented only on a sorted list of items. If the elements are not sorted already, we need to sort them first.

# %% [markdown]
# - Binary Search Algorithm can be implemented in two ways which are discussed below.
#
# 1. Iterative Method
# 2. Recursive Method
#
# Practinced details: https://www.programiz.com/dsa/binary-search

# %% [markdown]
# Time Complexities
#
# - Best case complexity: O(1)
# - Average case complexity: O(log n)
# - Worst case complexity: O(log n)
#
# Space Complexity: O(1)
#
#
# ### Binary Search Applications
# - In libraries of Java, .Net, C++ STL
# - While debugging, the binary search is used to pinpoint the place where the error happens.

# %% [markdown]
# #### 8.3 find a common elemnet in two list [Example problem]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Code Example
import random

l1 = list(range(100))
random.shuffle(l1)

l2 = list(range(50))
random.shuffle(l2)

count = 0;

#finding common elemnt: TC:  O(m*n)

for i in l1:
    for j in l2:
        if i==j:
            print(i)
            count +=1;
print("Total coommon elenmts are: ", count)
# Out:
# 30
# 43
# 1
# 34
# 45
# 14
# 20
# 25
# 40
# 21
# 8
# 7
# 36
# 3
# 13
# 18
# 37
# 44
# 39
# 42
# 26
# 33
# 28
# 19
# 27
# 4
# 38
# 10
# 5
# 12
# 41
# 35
# 22
# 24
# 17
# 48
# 32
# 23
# 0
# 49
# 16
# 11
# 46
# 31
# 29
# 6
# 9
# 47
# 2
# 15
# Total coommon elenmts are:  50

# %% [markdown]
# #####  Time complexity: O(m*n)
# #####  Space complexity: O(1)

# %% [markdown]
# ##### 8.4 Can we improve the complexity? Trade off!

# %%
#Dictonary [often known as Hashmap or HashTable]

# d.get[keyvalue]     Greatest property of dict

l1 = list(range(100))
random.shuffle(l1)

l2 = list(range(50))
random.shuffle(l2)

#   m<n
#Add all elemnts of small list into a Hashtable/Dict: O(m) space Complx

Dict1 = {}
for element in l2:
    Dict1[element] =2;  #Any Key is OK. leKin Key dena Zaruri hai

#print(Dict1)  #Just to Check remove 1st #
count=0;
for a in l1:
    if Dict1.get(a)  !=None:  #Search happan in constant line
        print(a);
        count+=1;
print("Number of Common elmnt is: ", count)
# Out:
# 45
# 4
# 37
# 30
# 3
# 1
# 46
# 33
# 47
# 19
# 43
# 25
# 39
# 14
# 38
# 36
# 10
# 42
# 0
# 12
# 8
# 21
# 34
# 23
# 5
# 41
# 17
# 48
# 6
# 44
# 11
# 26
# 2
# 16
# 49
# 22
# 20
# 27
# 32
# 13
# 29
# 7
# 9
# 15
# 24
# 40
# 31
# 35
# 18
# 28
# Number of Common elmnt is:  50

# %% [markdown]
# ### contents
# 1. Time Space comlexity Basic Idea
# 2. Binary Search
# 3. Findinf a common elnet in two list
# 4. Finding a common elemnt using Hastable/Dict (Tradeoff)
