# %% [markdown]
# # Function Part-2:
#
#
# # PYTHON MODULE AND PACKAGES

# %% [markdown]
# ## MODULE
#
# - Modules: file containing python statemnts and definitions
#
# - A file containing code, eg:  abc.py is module with name abc
#
# ###### Examples

# %%
#Example1

import math as mt                  #importing and renaming as per convenience 
print(mt.pi)


#Example2
from datetime import datetime as dt
dt.now()
# Out:
# 3.141592653589793
# datetime.datetime(2022, 8, 20, 4, 22, 1, 366472)

# %% [markdown]
# #### Importing all Names

# %%
from math import *     #similar:  from mathh import [pi and all other defintns]
print(pi)

#dir()  wali list se dekhne ke baad
print(sqrt(400)) 
print(cos(pi))
# Out:
# 3.141592653589793
# 20.0
# -1.0

# %% [markdown]
# ###### dir() function use to all the names defined inside a module

# %%
import math 
dir(math)      #prints list of definitions inside a module
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc']

# %% [markdown]
# ##### __doc__   tells us what each names does

# %%
from math import *
print(sin.__doc__)
print(radians.__doc__)
# Out:
# Return the sine of x (measured in radians).
# Convert angle x from degrees to radians.

# %%
theta = radians(46)
print(tan(theta))
# Out:
# 1.0355303137905696

# %% [markdown]
# ###### PS: Always write docs string when you write a code so other can understand what your code can do
#
# # -
#
# # -

# %% [markdown]
# # Python: Package

# %% [markdown]
# - PAKAGES ARE NOTHING BUT
#
# - WAYS OF ORGANIGING MODULES INTO A DIRECTORY
#
# - IT MUST CONTAIN A FILE NAME __init__.py  in way shown below to consider python as a diroctrory

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### we can import modules from pakages useing dot(.) opertor

# %%
#import game.Image.open     ::like this
